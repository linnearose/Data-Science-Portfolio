# %% [markdown]
# ## Basic data cleaning & EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
# Read in scraped data from poshmark.com
df = pd.read_csv('all_posts.csv', index_col=0)

# %%
df.tail(3)
# Out:
#             brand                                        description  \
# 11707  eric + ani  White very light weight top. Sparkly pear grap...
# 11708         BKE                                          33X33 1/2
# 11709        Nike             NEW WOMENS NIKE AIR MAX 95’ SE GLITTER
#
#                         item_id            price   status  \
# 11707  5c48fdee9539f7b6b5c3e2db    ['$5', '$25']  Buy Now
# 11708  5c48fe7a409c15e95d761881   ['$30', '$45']  Buy Now
# 11709  5c48fe4003087c8aaef53fab  ['$75', '$170']  Buy Now
#
#                                            tags  \
# 11707  ['Women', 'Tops', 'Tees - Short Sleeve']
# 11708            ['Women', 'Jeans', 'Boot Cut']
# 11709            ['Women', 'Shoes', 'Sneakers']
#
#                                         title  \
# 11707             Eric + ani pear sparkly top
# 11708                        BKE Payton Jeans
# 11709  NEW WOMENS NIKE AIR MAX 95’ SE GLITTER
#
#                                                      url
# 11707  https://poshmark.com/listing/Eric-ani-pear-spa...
# 11708  https://poshmark.com/listing/BKE-Payton-Jeans-...
# 11709  https://poshmark.com/listing/NEW-WOMENS-NIKE-A...

# %%
# Check for duplicate rows
df.duplicated(subset=['item_id']).sum()
# Out:
# 1

# %%
# Find which rows are duplicated
dup = df[df.duplicated(subset=['item_id']) == True].index[0]

# %%
# Drop any null rows
df.drop(index=dup, inplace=True)

# Now that rows have been deleted, reset the index
df.reset_index(inplace=True, drop=True)

# %%
# Check for nulls using item_id column
df['item_id'].isnull().sum()
# Out:
# 1

# %%
# Find which rows are null
ind = df[df['item_id'].isnull()].index[0]

# %%
# Drop any null rows
df.drop(index=ind, inplace=True)

# Now that rows have been deleted, reset the index
df.reset_index(inplace=True, drop=True)

# %%
try:
    ind = df[df['price'].isnull()].index[0]
except:
    pass

# %%
# Drop any null rows
df.drop(index=ind, inplace=True)

# Now that rows have been deleted, reset the index
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# #### Clean up `price` column

# %%
# Clean up 'price' column by removing extraneous characters in string
# Split 'price' into a list of 2 strings; original and new price
for i in range(len(df)):
    df['price'][i] = df['price'][i].replace("'", "").replace('$', '').replace('[', '').replace(']', '').replace(' ', '').split(',')

# %%
# Create empty DataFrame (df2) with identical index to main DataFrame (df)
df2 = pd.DataFrame(columns=['original_price', 'new_price'], 
                   index=df.index)

# %%
# Set df2 columns as new_price and original_price
for i in range(len(df)):
    df2['new_price'][i] = df['price'][i][0]
    df2['original_price'][i] = df['price'][i][1]

# %%
df2.head(3)
# Out:
#   original_price new_price
# 0             40        35
# 1            340       115
# 2             24        15

# %%
# Concatenate df and df2
df = pd.concat([df, df2], axis=1)

# %%
df.head(3)
# Out:
#          brand                                        description  \
# 0      Benefit  Includes full size Bad Gal Lash black, full si...
# 1        Reiss  Reiss Geometric Print Silk Dress. Size US 8. L...
# 2  Urban Decay             Fabulous Urban Decay eyeshadow primer.
#
#                     item_id       price   status  \
# 0  5c8fdb59409c15d1a7284952    [35, 40]  Buy Now
# 1  5c8fdba3035cf175a59fe617  [115, 340]  Buy Now
# 2  5c8fdb58c89e1dbee824798b    [15, 24]  Buy Now
#
#                                 tags  \
# 0     ['Women', 'Makeup', 'Mascara']
# 1               ['Women', 'Dresses']
# 2  ['Women', 'Makeup', 'Eye Primer']
#
#                                                title  \
# 0  Nwt Benefit Triple Decker Decadence Makeup Set
# 1                   Reiss Geometric Print Silk Dress
# 2                              Urban Decay primer
#
#                                                  url original_price new_price
# 0  https://poshmark.com/listing/Nwt-Benefit-Tripl...             40        35
# 1  https://poshmark.com/listing/Reiss-Geometric-P...            340       115
# 2  https://poshmark.com/listing/Urban-Decay-prime...             24        15

# %%
# Check datatypes
df.dtypes
# Out:
# brand             object
# description       object
# item_id           object
# price             object
# status            object
# tags              object
# title             object
# url               object
# original_price    object
# new_price         object
# dtype: object

# %%
# Set price columns as floats instead of strings
df['original_price'] = df['original_price'].astype(float)
df['new_price'] = df['new_price'].astype(float)

# %%
# Check datatypes again
df.dtypes
# Out:
# brand              object
# description        object
# item_id            object
# price              object
# status             object
# tags               object
# title              object
# url                object
# original_price    float64
# new_price         float64
# dtype: object

# %%
# Drop old 'price' column
df.drop(columns=['price'], inplace=True)

# %%
df.head(3)
# Out:
#          brand                                        description  \
# 0      Benefit  Includes full size Bad Gal Lash black, full si...
# 1        Reiss  Reiss Geometric Print Silk Dress. Size US 8. L...
# 2  Urban Decay             Fabulous Urban Decay eyeshadow primer.
#
#                     item_id   status                               tags  \
# 0  5c8fdb59409c15d1a7284952  Buy Now     ['Women', 'Makeup', 'Mascara']
# 1  5c8fdba3035cf175a59fe617  Buy Now               ['Women', 'Dresses']
# 2  5c8fdb58c89e1dbee824798b  Buy Now  ['Women', 'Makeup', 'Eye Primer']
#
#                                                title  \
# 0  Nwt Benefit Triple Decker Decadence Makeup Set
# 1                   Reiss Geometric Print Silk Dress
# 2                              Urban Decay primer
#
#                                                  url  original_price  \
# 0  https://poshmark.com/listing/Nwt-Benefit-Tripl...            40.0
# 1  https://poshmark.com/listing/Reiss-Geometric-P...           340.0
# 2  https://poshmark.com/listing/Urban-Decay-prime...            24.0
#
#    new_price
# 0       35.0
# 1      115.0
# 2       15.0

# %%
df[['original_price', 'new_price']].describe()
# Out:
#        original_price     new_price
# count    11707.000000  11707.000000
# mean       400.202187     48.786111
# std      13491.587086    144.502359
# min          0.000000      3.000000
# 25%          0.000000     15.000000
# 50%         40.000000     25.000000
# 75%         89.000000     40.000000
# max    1000000.000000   4950.000000

# %%
# How many 'original_price' are $0?
len(df[df['original_price'] == 0].sort_values(by='new_price'))
# Out:
# 2988

# %%
# How many observations are viable when we erase all observations where `original_price` = 0?
len(df) - len(df[df['original_price'] == 0].sort_values(by='new_price'))
# Out:
# 8719

# %%
# All data, minus all rows where 'original_price' == 0
no_zero = df[df['original_price'] != 0]

# %%
no_zero.describe()
# Out:
#        original_price    new_price
# count     8719.000000  8719.000000
# mean       537.351416    52.371029
# std      15631.237949   149.728332
# min          1.000000     3.000000
# 25%         35.000000    15.000000
# 50%         60.000000    25.000000
# 75%        110.000000    45.000000
# max    1000000.000000  4500.000000

# %%
# Find rows where original_price > 500 and sort from highest to lowest AS
df[df['original_price'] > 500].sort_values(by='original_price',
                                        ascending=False)
# Out:
#                       brand  \
# 1971                    NaN
# 6004   biviel anthropologie
# 11316       Violet & Claire
# 9599                 Reebok
# 7990                    NaN
# 1649       Staring at Stars
# 6815                   Fila
# 1159                    NaN
# 3471                   Mudd
# 6668                    NaN
# 5156     Kut from the Kloth
# 1242                    NaN
# 1394                    NaN
# 9040                   Zara
# 8451     Yves Saint Laurent
# 5664                 Matana
# 5935                LuLaRoe
# 9298            Free People
# 9573         Maia Sarmanian
# 10374              Dion Lee
# 8637                    GAP
# 9339                    NaN
# 10336                   all
# 10698                   NaN
# 5827                   LOFT
# 8009              A new day
# 2464           Silver Jeans
# 2154             wild fable
# 3023                    NaN
# 10611                   NaN
# ...                     ...
# 4356         Rebecca Taylor
# 11506                 Gucci
# 4457                  Gucci
# 10274                 Prada
# 5620        Stuart Weitzman
# 4886               Burberry
# 8992        Dolce & Gabbana
# 7419           Matt Bernson
# 8088                 CHANEL
# 8849                  Fendi
# 10190            Nena & Co.
# 1571                Miss Me
# 1620                  Coach
# 433                     NaN
# 4862        Wilsons Leather
# 9628          Louis Vuitton
# 6784                    NaN
# 8319                 Jovani
# 3792          La CANADIENNE
# 2420                 Jordan
# 6061               St. John
# 7319   MICHAEL Michael Kors
# 3163          Louis Vuitton
# 8036          Louis Vuitton
# 3431            Free People
# 9513          Tiffany & Co.
# 63       Fiorentini + Baker
# 11583       marques almeida
# 1023                  Gucci
# 8310             Johnny Was
#
#                                              description  \
# 1971   The length of the shirt from the top of the ba...
# 6004                                 Good used condition
# 11316                  Ruffled in the front\nLightweight
# 9599   Used shoes. Still have lots of life in them. S...
# 7990   Happy to negotiate! \nI accept reasonable offe...
# 1649          Gently pre-owned. No holes or stains. EUC!
# 6815   Fils Skirt Skort Gray Size M workout Tennis \n...
# 1159   Handwoven Wool panels in classic Zapotec style...
# 3471   Gray and white sweater by Mudd. Size large. Sh...
# 6668                           Great condition pre owned
# 5156          Gently pre-owned. No holes or stains. EUC!
# 1242   Razor Back Leopard Tank\nLike New Condition\n9...
# 1394                  Size 9\nWorn but in good condition
# 9040   Soft light sweater type hi-low top from Zara m...
# 8451                            Good as new dust bag box
# 5664   Orchid Statement earrings featuring handmade, ...
# 5935   LuLaRoe/LLR Colorful Splattered Leggings ~ TC ...
# 9298   Khaki and purple in color beautiful brand new ...
# 9573                  Super cute leather designer jacket
# 10374                            Like new. UK 6 or US 2.
# 8637                        no tags, no box , never worn
# 9339   Good used condition black romper stretchy wais...
# 10336                                 CLOSET INFORMATION
# 10698  Get that Midas Touch with this beautiful blous...
# 5827   LOFT Shirt S Black/White Bird Print Back Bow T...
# 8009   A New Day White Myla Stiletto Heels 8 Open Toe...
# 1242                ['Women', 'Tops', 'Tank Tops']
# 1394                 ['Women', 'Jewelry', 'Rings']
# 9040                             ['Women', 'Tops']
# 8451                   ['Women', 'Shoes', 'Heels']
# 5664              ['Women', 'Jewelry', 'Earrings']
# 5935                ['Women', 'Pants', 'Leggings']
# 9298                  ['Women', 'Dresses', 'Mini']
# 9573                  ['Women', 'Jackets & Coats']
# 10374                            ['Women', 'Tops']
# 8637         ['Women', 'Shoes', 'Flats & Loafers']
# 9339                          ['Women', 'Dresses']
# 10336                     ['Women', 'Accessories']
# 10698                 ['Women', 'Tops', 'Blouses']
# 5827                  ['Women', 'Tops', 'Blouses']
# 8009                   ['Women', 'Shoes', 'Heels']
# 2464                ['Women', 'Jeans', 'Boot Cut']
# 2154                ['Women', 'Tops', 'Crop Tops']
# 3023                            ['Women', 'Other']
# 10611             ['Women', 'Jewelry', 'Brooches']
# ...                                            ...
# 4356                  ['Women', 'Dresses', 'Mini']
# 11506            ['Women', 'Shoes', 'Espadrilles']
# 4457           ['Women', 'Bags', 'Crossbody Bags']
# 10274          ['Women', 'Bags', 'Crossbody Bags']
# 5620   ['Women', 'Shoes', 'Ankle Boots & Booties']
# 4886                  ['Women', 'Dresses', 'Midi']
# 8992             ['Women', 'Shoes', 'Espadrilles']
# 7419     ['Women', 'Shoes', 'Winter & Rain Boots']
# 8088        ['Women', 'Accessories', 'Sunglasses']
# 8849     ['Women', 'Bags', 'Clutches & Wristlets']
# 10190                            ['Women', 'Bags']
# 1571                            ['Women', 'Jeans']
# 1620                 ['Women', 'Bags', 'Satchels']
# 433            ['Women', 'Bags', 'Crossbody Bags']
# 4862       ['Women', 'Jackets & Coats', 'Blazers']
# 9628     ['Women', 'Bags', 'Clutches & Wristlets']
# 6784       ['Women', 'Jackets & Coats', 'Puffers']
# 8319                  ['Women', 'Dresses', 'Prom']
# 3792            ['Women', 'Shoes', 'Heeled Boots']
# 2420                ['Women', 'Shoes', 'Sneakers']
# 6061            ['Women', 'Sweaters', 'Cardigans']
# 7319                  ['Women', 'Jackets & Coats']
# 3163                  ['Women', 'Bags', 'Wallets']
# 8036                  ['Women', 'Bags', 'Wallets']
# 3431     ['Women', 'Shoes', 'Over the Knee Boots']
# 9513             ['Women', 'Jewelry', 'Necklaces']
# 63     ['Women', 'Shoes', 'Ankle Boots & Booties']
# 11583                            ['Women', 'Tops']
# 1023         ['Women', 'Shoes', 'Flats & Loafers']
# 8310         ['Women', 'Jackets & Coats', 'Capes']
#
#                                                    title  \
# 1971                                Black&White Lace Top
# 6004    Biviel Anthropologie tan sandals sz 40 9.5 suede
# 11316           Violet + Claire Lightweight Green Blouse
# 9599                     Reebok Runtone Shoes and Tshirt
# 7990                                  Like it! Get it!🛍🥰
# 1649   Staring at Stars Urban Outfitters Button Flowy...
# 6815         Fils Skirt Skort Gray Size M workout Tennis
# 1159                             Saddle Blanket Purse
# 3471   Gray & white cowl neck sweater by mudd. Size l...
# 6668                                 Xl tignanello purse
# 3792   https://poshmark.com/listing/La-Canadienne-Wat...           550.0
# 2420   https://poshmark.com/listing/Jordan-11-concord...           550.0
# 6061   https://poshmark.com/listing/St-John-sweater-k...           550.0
# 7319   https://poshmark.com/listing/Michael-Kors-Leat...           550.0
# 3163   https://poshmark.com/listing/Louis-Vuitton-mon...           550.0
# 8036   https://poshmark.com/listing/Authentic-lv-Wall...           550.0
# 3431   https://poshmark.com/listing/Free-people-thigh...           548.0
# 9513   https://poshmark.com/listing/Tiffany-Co-Oval-T...           548.0
# 63     https://poshmark.com/listing/FIORENTINIBAKER-E...           530.0
# 11583  https://poshmark.com/listing/MARQUES-ALMEIDA-f...           525.0
# 1023   https://poshmark.com/listing/Gucci-leather-dri...           520.0
# 8310   https://poshmark.com/listing/Johnny-Was-Sweate...           506.0
#
#        new_price
# 1971         5.0
# 6004        39.0
# 11316       15.0
# 9599        25.0
# 7990      1000.0
# 1649        14.0
# 6815        28.0
# 1159        45.0
# 3471        28.0
# 6668        25.0
# 5156        14.0
# 1242        15.0
# 1394         8.0
# 9040         8.0
# 8451       350.0
# 5664       169.0
# 5935        13.0
# 9298       100.0
# 9573        75.0
# 10374      225.0
# 8637        15.0
# 9339        12.0
# 10336     1000.0
# 10698       10.0
# 5827        25.0
# 8009        16.0
# 2464        25.0
# 2154        18.0
# 3023        10.0
# 10611       20.0
# ...          ...
# 4356       300.0
# 11506      250.0
# 4457       300.0
# 10274      275.0
# 5620       249.0
# 4886        90.0
# 8992        89.0
# 7419       200.0
# 8088        50.0
# 8849       159.0
# 10190      560.0
# 1571       444.0
# 1620       315.0
# 433        400.0
# 4862       110.0
# 9628       380.0
# 6784       229.0
# 8319       295.0
# 3792       150.0
# 2420       525.0
# 6061       199.0
# 7319       225.0
# 3163       155.0
# 8036       269.0
# 3431       230.0
# 9513       345.0
# 63         100.0
# 11583      125.0
# 1023       179.0
# 8310       340.0
#
# [400 rows x 9 columns]

# %% [markdown]
# #### Clean up `tags` column

# %%
# Look at tags column structure
df['tags'][3]
# Out:
# "['Women', 'Dresses']"

# %%
# Clean up 'tags' column by removing extraneous characters
# Split 'tags' into a list of strings; each string a different tag
for i in range(len(df)):
    df['tags'][i] = df['tags'][i].replace('[', '').replace(']', '').replace(' ', '').replace("'", "").split(',')
    
    if i % 1000 == 0: # Show progress of cleaning
        print(i)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000

# %%
df['tags'][1]
# Out:
# ['Women', 'Dresses']

# %%
# Create empty DataFrame (df3) with identical index to main DataFrame (df)
df3 = pd.DataFrame(columns=['tag_1', 'tag_2', 'tag_3'], index=df.index)

# %%
# Split 'tags' column into three separate columns
for i in range(len(df)):
    df3['tag_1'][i] = str(df['tags'][i][0])
    
    # There isn't always a 2nd and 3rd tag, they're left null
    try:
        df3['tag_2'][i] = str(df['tags'][i][1])
        df3['tag_3'][i] = str(df['tags'][i][2])
    
    except:
        df3['tag_2'][i] = None
        df3['tag_3'][i] = None

# %%
# Concatenate df and df3
df = pd.concat([df, df3], axis=1)

# %%
# Drop old 'tags' column
df.drop(columns=['tags'], inplace=True)

# %%
df.head(3)
# Out:
#          brand                                        description  \
# 0      Benefit  Includes full size Bad Gal Lash black, full si...
# 1        Reiss  Reiss Geometric Print Silk Dress. Size US 8. L...
# 2  Urban Decay             Fabulous Urban Decay eyeshadow primer.
#
#                     item_id   status  \
# 0  5c8fdb59409c15d1a7284952  Buy Now
# 1  5c8fdba3035cf175a59fe617  Buy Now
# 2  5c8fdb58c89e1dbee824798b  Buy Now
#
#                                                title  \
# 0  Nwt Benefit Triple Decker Decadence Makeup Set
# 1                   Reiss Geometric Print Silk Dress
# 2                              Urban Decay primer
#
#                                                  url  original_price  \
# 0  https://poshmark.com/listing/Nwt-Benefit-Tripl...            40.0
# 1  https://poshmark.com/listing/Reiss-Geometric-P...           340.0
# 2  https://poshmark.com/listing/Urban-Decay-prime...            24.0
#
#    new_price  tag_1   tag_2      tag_3
# 0       35.0  Women  Makeup    Mascara
# 1      115.0  Women    None       None
# 2       15.0  Women  Makeup  EyePrimer

# %%
# Check dtypes again
df.dtypes
# Out:
# brand              object
# description        object
# item_id            object
# status             object
# title              object
# url                object
# original_price    float64
# new_price         float64
# tag_1              object
# tag_2              object
# tag_3              object
# dtype: object

# %%
# # See how many posts are in each specific category by tag
# len(df[df['tag_2'] == 'Tops'])

# %%
# # Total # of unique tag_2 tags
# set(df['tag_2'])

# %%
# # Total # of unique tag_3 tags
# set(df['tag_3'])

# %% [markdown]
# #### Look at `brand` column

# %%
len(set(df['brand']))
# Out:
# 2656

# %%
# Value count by brand
brand_counts = pd.DataFrame(df['brand'].value_counts())

# %%
# Top 10 brands based on post count
brand_counts[brand_counts['brand'] > 20].head(10)
# Out:
#                            brand
# Nike                         204
# Forever 21                   203
# lululemon athletica          191
# American Eagle Outfitters    178
# LuLaRoe                      177
# Free People                  176
# J. Crew                      158
# PINK Victoria's Secret       156
# Victoria's Secret            154
# Anthropologie                130

# %%
df.tail(3)
# Out:
#             brand                                        description  \
# 11704  eric + ani  White very light weight top. Sparkly pear grap...
# 11705         BKE                                          33X33 1/2
# 11706        Nike             NEW WOMENS NIKE AIR MAX 95’ SE GLITTER
#
#                         item_id   status  \
# 11704  5c48fdee9539f7b6b5c3e2db  Buy Now
# 11705  5c48fe7a409c15e95d761881  Buy Now
# 11706  5c48fe4003087c8aaef53fab  Buy Now
#
#                                         title  \
# 11704             Eric + ani pear sparkly top
# 11705                        BKE Payton Jeans
# 11706  NEW WOMENS NIKE AIR MAX 95’ SE GLITTER
#
#                                                      url  original_price  \
# 11704  https://poshmark.com/listing/Eric-ani-pear-spa...            25.0
# 11705  https://poshmark.com/listing/BKE-Payton-Jeans-...            45.0
# 11706  https://poshmark.com/listing/NEW-WOMENS-NIKE-A...           170.0
#
#        new_price  tag_1  tag_2             tag_3
# 11704        5.0  Women   Tops  Tees-ShortSleeve
# 11705       30.0  Women  Jeans           BootCut
# 11706       75.0  Women  Shoes          Sneakers

# %%
df.to_csv('./clean_data_1.csv')
